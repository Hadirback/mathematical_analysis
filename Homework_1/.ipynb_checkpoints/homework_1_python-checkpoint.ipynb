# %%
import math

# %% [markdown]
# 1. Даны три множества a,b и с. Необходимо выполнить все изученные виды бинарных операций над всеми комбинациями множеств.

# %%
a = set('538512')
b = set('2780')
c = set('3')

union_a_b = a.union(b)
print(union_a_b)
union_a_c = a.union(c)
print(union_a_c)
intersection_a_c = a.intersection(c)
print(intersection_a_c)
intersection_a_b = a.intersection(b)
print(intersection_a_b)
diff_a_b = a.difference(b)
print(diff_a_b)
diff_b_a = b.difference(a)
print(diff_b_a)
symmetric_diff_a_b = a.symmetric_difference(b)
print(symmetric_diff_a_b)
# Out:
# {'5', '3', '0', '1', '7', '8', '2'}
# {'5', '8', '3', '2', '1'}
# {'3'}
# {'8', '2'}
# {'5', '3', '1'}
# {'7', '0'}
# {'5', '3', '0', '1', '7'}

# %% [markdown]
# На языке Python предложить алгоритм вычисляющий численно предел с точностью

# %%
def func(n):
    return float(n / (math.factorial(n)**(1/n)))

acc = 0.0000001
i = 2
while True:
    val = float(func(i) - func(i - 1))
    print(func(i))
    
    if(val < acc):
        break
        
    i = i + 1
# Out:
# 1.414213562373095
# 1.6509636244473134
# 1.8072040072196898
# 1.9192597481868872
# 2.0041451295984074
# 2.070996628837124
# 2.1252005594420327
# 2.170156536901524
# 2.2081252132060087
# 2.2406732477028206
# 2.268923390819235
# 2.2937029551771286
# 2.3156360189017344
# 2.335202883868812
# 2.352779665665871
# 2.368665391348515
# 2.3831009973869577
# 2.396282932872044
# 2.408373083650825
# 2.419506134182143
# 2.429795111070674
# 2.4393356142427107
# 2.448209086349558
# 2.4564853674650906
# 2.46422471189274
# 2.471479395415468
# 2.478295007345771
# 2.484711497582766
# 2.4907640314928114
# 2.496483692754992
# 2.501898064970579
# 2.5070317158777042
# 2.511906602779828
# 2.5165424138253716
# 2.5209568567362743
# 2.525165904237891
# 2.5291840036193896
# 2.533024256426202
# 2.5366985731609004
# 2.5402178069761545
# 2.5435918696311526
# 2.546829832411064
# 2.549940014247768
# 2.552930058905755
# 2.5558070027920627
# 2.5585773346992244
# 2.5612470485846335
# 2.5638216903199083
# 2.5663063992029502
# 2.568705944908037
# 2.571024760451175
# 2.5732669716656855
# 2.5754364236136276
# 2.57753670430019
# 2.579571166008542
# 2.5815429445304647
# 2.5834549765321584
# 2.5853100152638544
# 2.5871106447955117
# 2.588859292938235
# 2.5905582429914977
# 2.592209644439393
# 2.593815522704537
# 2.595377788055523
# 2.596898243752819
# 2.5983785935083703
# 2.599820448325733
# 2.6012253327802406
# 2.602594690792201
# 2.6039298909404622
# 2.6052322313586966
# 2.6065029442522945
# 2.607743200069914
# 2.60895411136023
# 2.6101367363413814
# 2.611292082207907
# 2.6124211081975277
# 2.6135247284379473
# 2.614603814591984
# 2.615659198317556
# 2.616691673557546
# 2.617701998673183
# 2.618690898433316
# 2.6196590658708807
# 2.6206071640168287
# 2.6215358275208946
# 2.622445664167764
# 2.6233372562964754
# 2.6242111621302104
# 2.6250679170230424
# 2.625908034629652
# 2.6267320080035232
# 2.6275403106287274
# 2.628333397389902
# 2.6291117054847692
# 2.6298756552831164
# 2.6306256511358934
# 2.631362082137783
# 2.6320853228463696
# 2.632795733960734
# 2.633493662962183
# 2.6341794447195244
# 2.634853402061185
# 2.6355158463162907
# 2.636167077826631
# 2.6368073864313595
# 2.63743705192611
# 2.638056344498083
# 2.638665525138585
# 2.6392648460343446
# 2.6398545509389253
# 2.640434875525355
# 2.641006047721124
# 2.6415682880265345
# 2.642121809817405
# 2.6426668196329803
# 2.64320351744993
# 2.643732096943174
# 2.64425274573431
# 2.6447656456283077
# 2.64527097283911
# 2.6457688982047602
# 2.646259587392613
# 2.646743201095152
# 2.647219895216943
# 2.6476898210531465
# 2.6481531254600723
# 2.648609951018167
# 2.649060436187825
# 2.6495047154584106
# 2.649942919490798
# 2.650375175253807
# 2.6508016061547823
# 2.6512223321646635
# 2.651637469937776
# 2.6520471329266164
# 2.6524514314918823
# 2.6528504730079683
# 2.653244361964142
# 2.653633200061613
# 2.654017086306688
# 2.654396117100196
# 2.6547703863233463
# 2.655139985420205
# 2.6555050034769296
# 2.6558655272979106
# 2.656221641478973
# 2.656573428477758
# 2.656920968681406
# 2.6572643404716896
# 2.6576036202876674
# 2.6579388826860053
# 2.6582702003990493
# 2.6585976443907415
# 2.6589212839104848
# 2.6592411865450423
# 2.659557418268552
# 2.659870043490728
# 2.660179125103347
# 2.660484724525065
# 2.6607869017446513
# 2.661085715362705
# 2.661381222631906
# 2.6616734794958634
# 2.6619625406266247
# 2.6622484594608973
# 2.6625312882350265
# 2.6628110780187835
# 2.663087878748024
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-10-93324d7fe935> in <module>
#       5 i = 2
#       6 while True:
# ----> 7     val = float(func(i) - func(i - 1))
#       8     print(func(i))
#       9
#
# <ipython-input-10-93324d7fe935> in func(n)
#       1 def func(n):
# ----> 2     return float(n / (math.factorial(n)**(1/n)))
#       3
#       4 acc = 0.0000001
#       5 i = 2
#
# OverflowError: int too large to convert to float

# %% [markdown]
# Предложить оптимизацию алгоритма, полученного в задании 3, ускоряющую его сходимость.
